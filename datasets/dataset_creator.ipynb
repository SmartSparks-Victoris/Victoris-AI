# %%
import pandas as pd

df1 = pd.read_csv("D:\Programming\IEEE Victoris\Smart Sparks\Victoris-AI\datasets\Chat_Classification_Dataset.csv")
df2 = pd.read_csv("D:\Programming\IEEE Victoris\Smart Sparks\Victoris-AI\datasets\Customer_Chat_and_Sentiment_Dataset.csv")
df3 = pd.read_csv("D:\Programming\IEEE Victoris\Smart Sparks\Victoris-AI\datasets\customer_chat_dataset.csv")
df4 = pd.read_csv("D:\Programming\IEEE Victoris\Smart Sparks\Victoris-AI\datasets\Final_Corrected_Customer_Chat_Sentiment_Dataset.csv")

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df.drop_duplicates(inplace=True)
df.to_csv("D:\Programming\IEEE Victoris\Smart Sparks\Victoris-AI\datasets\Combined_Customer_Chat_Dataset.csv", index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Create DataFrame
df = pd.DataFrame(data)

# Display the dataframe to the user
import ace_tools as tools; tools.display_dataframe_to_user(name="Customer Chat Dataset", dataframe=df)

# Save the dataset to a CSV file
file_path = "/mnt/data/customer_chat_dataset.csv"
df.to_csv(file_path, index=False)

file_path

# %%
import pandas as pd

# Define the target classes and sentiments
target_classes = ["feedback", "support", "orders", "complaint", "other"]
target_sentiments = ["positive", "negative", "neutral"]

# Sample chat histories
chat_histories = [
    # English examples
    '"""Customer: I can\'t log in to my account. Admin: Let me assist you."""',
    '"""Customer: I love your service! Admin: Thank you!"""',
    '"""Customer: I\'m not happy with my order. Admin: I\'m sorry to hear that."""',
    '"""Customer: I added my order but haven\'t received confirmation yet. Admin: We will check it out."""',
    '"""Customer: The website is not working properly. Admin: We are fixing the issue."""',
    '"""Customer: How can I change my delivery address? Admin: Let me assist you."""',
    '"""Customer: I have a complaint about your support. Admin: We apologize for the inconvenience."""',
    '"""Customer: I need help tracking my order. Admin: Sure, I will track it for you."""',
    '"""Customer: Your service is amazing. Admin: We appreciate your feedback!"""',
    '"""Customer: This product was defective. Admin: We will arrange a replacement."""',

    # Arabic examples
    '"""Customer: أحب خدمتكم! Admin: شكراً لك!"""',
    '"""Customer: لم أتمكن من تسجيل الدخول إلى حسابي. Admin: دعني أساعدك."""',
    '"""Customer: طلبي لم يصل بعد. Admin: سنبحث في الأمر."""',
    '"""Customer: لدي شكوى حول المنتج. Admin: نعتذر عن الإزعاج."""',
    '"""Customer: كيف يمكنني تغيير عنوان التوصيل؟ Admin: سأساعدك."""',
    '"""Customer: لم أحصل على الدعم المطلوب. Admin: نعتذر عن ذلك."""',
    '"""Customer: المنتج لا يعمل بشكل صحيح. Admin: سنعمل على استبداله."""',
    '"""Customer: لقد أضفت طلبي لكن لم أتلقَ تأكيداً. Admin: سنتحقق من الأمر."""',
    '"""Customer: الموقع لا يعمل بشكل جيد. Admin: نحن نعمل على حل المشكلة."""',
    '"""Customer: أنا سعيد جدًا بخدمتكم. Admin: شكراً لك!"""',
]

# Assign target classes and sentiments, ensuring balance
classes = [
    "support", "feedback", "complaint", "orders", "other",
    "support", "complaint", "support", "feedback", "complaint",
    "feedback", "support", "orders", "complaint", "other",
    "support", "complaint", "orders", "other", "feedback"
]

sentiments = [
    "negative", "positive", "negative", "negative", "neutral",
    "negative", "negative", "neutral", "positive", "negative",
    "positive", "negative", "negative", "negative", "neutral",
    "negative", "negative", "negative", "neutral", "positive"
]

# Create a DataFrame
data = {
    "chat_history": chat_histories,
    "target_class": classes,
    "target_sentiment": sentiments
}

df = pd.DataFrame(data)

# Display the dataset to the user
df.head()

df.to_csv("D:\Programming\IEEE Victoris\Smart Sparks\Victoris-AI\datasets/customer_chat_dataset.csv", index=False)

# %%
# Expand the dataset to 50 rows, maintaining balance and diversity in classes and sentiments
additional_chat_histories = [
    """Customer: I am facing issues with the payment. Admin: Let me assist you with that.""",
    """Customer: شكراً لخدمتكم الرائعة! Admin: شكرًا لك!""",
    """Customer: لم أعد أحتاج هذا المنتج. Admin: سنقوم بإلغاء الطلب.""",
    """Customer: There is a delay in my delivery. Admin: We apologize for the inconvenience.""",
    """Customer: How do I reset my password? Admin: I will guide you through the process.""",
    """Customer: What are the store hours? Admin: Our store is open 24/7.""",
    """Customer: My product arrived damaged. Admin: We will arrange for a replacement.""",
    """Customer: كيف يمكنني تتبع طلبي؟ Admin: سأقوم بتتبع الطلب لك.""",
    """Customer: The mobile app is crashing frequently. Admin: We are working on fixing that.""",
    """Customer: Your customer service is excellent. Admin: Thank you for your kind words!""",
    """Customer: Can I cancel my order? Admin: I will cancel it right away.""",
    """Customer: أواجه مشكلة في تسجيل الدخول. Admin: سأقوم بمساعدتك حالاً.""",
    """Customer: The refund is taking too long. Admin: We will expedite the process.""",
    """Customer: The packaging was not good. Admin: We apologize and will improve it.""",
    """Customer: I would like to leave feedback on your service. Admin: We appreciate it!""",
    """Customer: هل يمكنني تغيير طريقة الدفع؟ Admin: سأساعدك في ذلك.""",
    """Customer: My payment was declined. Admin: Let me check the issue for you.""",
    """Customer: Thank you for solving my issue quickly! Admin: Glad we could help!""",
    """Customer: المنتج لم يصلني بعد. Admin: نأسف للتأخير وسنتابع ذلك.""",
    """Customer: The checkout process is too slow. Admin: We are improving it.""",
    """Customer: Can I update my order? Admin: Sure, I will assist you.""",
    """Customer: I have a question about my refund. Admin: I will look into it for you.""",
    """Customer: لم أستلم رقم تتبع الشحنة. Admin: سنقوم بإرساله حالاً.""",
    """Customer: The website is very user-friendly! Admin: Thank you for your feedback!""",
    """Customer: My account was locked. Admin: Let me unlock it for you.""",
    """Customer: أحتاج إلى مساعدة في تتبع طلبي. Admin: سأقوم بمساعدتك.""",
    """Customer: I received the wrong product. Admin: We will fix this immediately.""",
    """Customer: This is the best service Ive experienced! Admin: We are glad to hear that!""",
    """Customer: أريد إرجاع المنتج. Admin: سنقوم بإرسال تفاصيل الإرجاع.""",
    """Customer: Thank you for the great service! Admin: We appreciate your feedback!"""
]

additional_classes = [
    "support", "feedback", "orders", "complaint", "support",
    "other", "complaint", "support", "complaint", "feedback",
    "orders", "support", "complaint", "complaint", "feedback",
    "orders", "support", "feedback", "orders", "complaint",
    "other", "orders", "feedback", "support", "complaint",
    "feedback", "orders", "feedback"
]

additional_sentiments = [
    "negative", "positive", "neutral", "negative", "neutral",
    "neutral", "negative", "neutral", "negative", "positive",
    "neutral", "negative", "negative", "neutral", "positive",
    "neutral", "negative", "positive", "negative", "neutral",
    "neutral", "negative", "positive", "negative", "negative",
    "positive", "neutral", "positive"
]

# Adding the additional 30 rows to the dataset
additional_data = {
    "chat_history": additional_chat_histories,
    "target_class": additional_classes,
    "target_sentiment": additional_sentiments
}

lengths = [len(additional_chat_histories), len(additional_classes), len(additional_sentiments)]
print(lengths)
# Out:
# [30, 28, 28]

# %%
# Convert to DataFrame
additional_df = pd.DataFrame(additional_data)

# Append to the original dataset
df_extended = pd.concat([df, additional_df], ignore_index=True)

# Display the extended dataset to the user
df_extended.head(), df_extended.tail()
